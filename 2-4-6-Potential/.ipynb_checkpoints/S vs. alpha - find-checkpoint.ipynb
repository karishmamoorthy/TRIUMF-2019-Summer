# %% [markdown]
# For 2-4-6 Potential

# %%
import numpy as np

# %%
alpha_vals = np.linspace(0.500001, 2.0/3.0, 50)

# %%
import Var_Hex_Pot_Act_3

# %%
s_vals = []
r_vals = []
p_vals = []
r10_vals = []

print("#    S     R    Phi_0,   r10,   case")
for a in alpha_vals:
    s, r, phi_0, case, r10 = Var_Hex_Pot_Act_3.get_S(a, D=4)
    s_vals.append(s)
    r_vals.append(r)
    p_vals.append(phi_0)
    r10_vals.append(r10)
    print(len(s_vals), s_vals[-1], r_vals[-1], p_vals[-1], r10_vals[-1], case)
# Out:
# #    S     R    Phi_0,   r10,   case
# Yikes
# 1 34802.90936335358 16.13099999999673 0.9999999999403059 13.2856585403904 True
# Yikes
# 2 30402.33204003256 16.058999999996644 0.999999999940736 13.154998540316585 True
# Yikes
# 3 25352.93558382361 15.791999999996687 0.9999999999131403 12.82611035322101 True
# Yikes
# 4 22635.778311419675 15.993999999996575 0.9999999999453337 12.939326340484401 True
# Yikes
# 5 18803.559850975973 15.882999999996636 0.9999999999354046 12.730980061710726 True
# Yikes
# 6 15402.801608225429 15.82099999999667 0.9999999999262976 12.545270722695646 True
# Yikes
# 7 12348.898633136287 15.818999999996672 0.9999999999177644 12.37523025167927 True
# Yikes
# 8 9589.955039320605 15.920999999996615 0.9999999999096572 12.216960577491005 True
# 9 7027.270191441383 15.188937856175897 0.999999999901879 12.068112644218381 True
# 10 4998.724261573027 14.287633102215567 0.9999999996302695 11.315811376431036 True
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
plt.close()
plt.plot(alpha_vals[2:], s_vals[2:], 'r.-')
plt.grid(True)
plt.title("S vs. alpha, 2-4-6- potential")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'S vs. alpha, 2-4-6- potential')

# %%
plt.close()

# %%
plt.close()
plt.plot(alpha_vals[2:], r_vals[2:], 'b.-')
plt.grid(True)
plt.title("R vs. alpha, 2-4-6- potential")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'R vs. alpha, 2-4-6- potential')

# %%
plt.close()

# %%
plt.close()
plt.plot(alpha_vals, p_vals, 'g.-')
plt.title("Initial values vs. alpha")
plt.xlabel("alpha")
plt.ylabel("Phi_0")
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

# %%
file = open("var_hex_pot_act_S_vals_3_dof4.txt", "w+")
for i in s_vals:
    file.write(str(i) + " \n")
file.close()

file = open("var_hex_pot_act_R_vals_3_dof4.txt", "w+")
for i in r_vals:
    file.write(str(i) + " \n")
file.close()

file = open("var_hex_pot_act_R10_vals_3_dof4.txt", "w+")
for i in r10_vals:
    file.write(str(i) + " \n")
file.close()

file = open("var_hex_pot_act_P_vals_3_dof4.txt", "w+")
for i in p_vals:
    file.write(str(i) + " \n")
file.close()
