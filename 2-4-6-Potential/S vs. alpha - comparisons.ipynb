# %% [markdown]
# # Compaing different approximations in calculating the Euclidean action, in the Bounce/Bubble approximation
#
# ## For 2-4-6 Potential

# %%
import numpy as np

# %%
s_v1 = []
r_v1 = []
p_v1 = []
s_v2 = []
r_v2 = []
p_v2 = []
s_v3 = []
r_v3 = []
p_v3 = []
s_v4 = []
r_v4 = []
p_v4 = []
s_v5 = []
r_v5 = []
p_v5 = []
r10_v5 = []
s_v6 = []
r_v6 = []
p_v6 = []
r10_v6 = []
s_v7 = []

alpha_vals = np.linspace(0.500001, 2.0/3.0, 50)
alpha_vals_final = np.linspace(0.5, 2.0/3.0, 201)[::-1]

file2 = open("var_hex_pot_act_S_vals_1.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        s_v1.append(float(word2))
file2.close()

file3 = open("var_hex_pot_act_R_vals_1.txt", "r")
for line3 in file3:
    for word3 in line3.split(): 
        r_v1.append(float(word3))
file3.close()

file5 = open("var_hex_pot_act_P_vals_1.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        p_v1.append(float(word5))
file5.close()

file4 = open("var_hex_pot_act_S_vals_2.txt", "r")
for line4 in file4:
    for word4 in line4.split(): 
        s_v2.append(float(word4))
file4.close()

file5 = open("var_hex_pot_act_R_vals_2.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        r_v2.append(float(word5))
file5.close()

file5 = open("var_hex_pot_act_P_vals_2.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        p_v2.append(float(word5))
file5.close()

file4 = open("var_hex_pot_act_S_vals_epsilon.txt", "r")
for line4 in file4:
    for word4 in line4.split(): 
        s_v4.append(float(word4))
file4.close()

file5 = open("var_hex_pot_act_R_vals_epsilon.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        r_v4.append(float(word5))
file5.close()

file5 = open("var_hex_pot_act_P_vals_epsilon.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        p_v4.append(float(word5))
file5.close()

file2 = open("S_alpha_246_template_dof_3_S_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        s_v3.append(float(word2))
file2.close()

file2 = open("S_alpha_246_template_dof_4_S_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        s_v7.append(float(word2))
file2.close()

file3 = open("S_alpha_246_template_dof_3_R_vals.txt", "r")
for line3 in file3:
    for word3 in line3.split(): 
        r_v3.append(float(word3))
file3.close()

file5 = open("S_alpha_246_template_dof_3_Phi_vals.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        p_v3.append(float(word5))
file5.close()

file4 = open("var_hex_pot_act_S_vals_3.txt", "r")
for line4 in file4:
    for word4 in line4.split(): 
        s_v5.append(float(word4))
file4.close()

file5 = open("var_hex_pot_act_R_vals_3.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        r_v5.append(float(word5))
file5.close()

file5 = open("var_hex_pot_act_P_vals_3.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        p_v5.append(float(word5))
file5.close()

file5 = open("var_hex_pot_act_R10_vals_3.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        r10_v5.append(float(word5))
file5.close()

file4 = open("var_hex_pot_act_S_vals_3_dof4.txt", "r")
for line4 in file4:
    for word4 in line4.split(): 
        s_v6.append(float(word4))
file4.close()

file5 = open("var_hex_pot_act_R_vals_3_dof4.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        r_v6.append(float(word5))
file5.close()

file5 = open("var_hex_pot_act_P_vals_3_dof4.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        p_v6.append(float(word5))
file5.close()

file5 = open("var_hex_pot_act_R10_vals_3_dof4.txt", "r")
for line5 in file5:
    for word5 in line5.split(): 
        r10_v6.append(float(word5))
file5.close()

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib nbagg

# %%
plt.close()
r_vals = np.array(r_v5)
r10_vals = np.array(r10_v5)
plt.plot(alpha_vals, r10_vals - r_vals, 'y.-')
plt.title("Rho at 90%(Phi_0) vs. 10%(Phi_0) in Version 3, for dof = 3")
plt.xlabel("alpha")
plt.ylabel("[rho at 90%(Phi_0)] - [R i.e. rho at 10%(Phi_0)]")
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="529">

# %%
plt.close()

# %%
plt.close()
r_vals_4 = np.array(r_v6)
r10_vals_4 = np.array(r10_v6)
plt.plot(alpha_vals, r10_vals_4 - r_vals_4, 'y.-')
plt.title("Rho at 90%(Phi_0) vs. 10%(Phi_0) in Version 3, for dof = 4")
plt.xlabel("alpha")
plt.ylabel("[rho at 90%(Phi_0)] - [R i.e. rho at 10%(Phi_0)]")
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="520">

# %%
plt.close()

# %%
plt.close()
plt.plot(alpha_vals_final[:-5], s_v3[:-5], 'k.-', label='Final version')
plt.plot(alpha_vals[1:], s_v4[1:], 'g.-', label='Pure epsilon approx.')
plt.plot(alpha_vals, s_v5, 'y.-', label='Version 3')
plt.plot(alpha_vals[1:], s_v2[1:], 'r.-', label='Version 2')
plt.plot(alpha_vals[1:], s_v1[1:], 'b.-', label='Version 1')
plt.title("Action as a function of alpha values, D = 3")
plt.xlabel("alpha")
plt.ylabel("S")
plt.legend()
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="839">

# %%
plt.close()

# %%
plt.close()
plt.plot(alpha_vals_final[:-5], r_v3[:-5], 'k.-', label='Final version')
plt.plot(alpha_vals[1:], r_v4[1:], 'g.-', label='Pure epsilon approx.')
plt.plot(alpha_vals, r_v5, 'y.-', label='Version 3')
plt.plot(alpha_vals[1:], r_v2[1:], 'r.-', label='Version 2')
plt.plot(alpha_vals[1:], r_v1[1:], 'b.-', label='Version 1')
plt.title("Bubble radius as a function of alpha values")
plt.xlabel("alpha")
plt.ylabel("R")
plt.legend()
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="785">

# %%
plt.close()

# %%
plt.close()
plt.plot(alpha_vals_final[:-5], p_v3[:-5], 'k.-', label='Final version')
plt.plot(alpha_vals, p_v4, 'g.-', label='Pure epsilon approx.')
plt.plot(alpha_vals, p_v5, 'y.-', label='Version 3')
plt.plot(alpha_vals, p_v2, 'r.-', label='Version 2')
plt.plot(alpha_vals, p_v1, 'b.-', label='Version 1')
plt.title("Initial phi values as a function of alpha values")
plt.xlabel("alpha")
plt.ylabel("Phi_0")
plt.legend()
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="719">

# %%
plt.close()

# %%
plt.close()
plt.plot(alpha_vals, s_v6, 'y.-', label='Version 3')
plt.plot(alpha_vals_final[:-6], s_v7[:-6], 'k.-', label='Final version')
plt.title("Action as a function of alpha values for dof=4")
plt.xlabel("alpha")
plt.ylabel("S")
plt.legend()
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="695">

# %%
plt.close()
