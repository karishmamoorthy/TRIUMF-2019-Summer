# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib nbagg

# %%
import Act_Temp_quick

# %%
import sys

# %%
import scipy.interpolate as sci

# %%
alpha_theory_examples = [0.51, 0.54, 0.57, 0.6, 0.64, 0.65, 0.68, 0.72, 0.75]

# %%
plt.close()

case1_bH = []
case2_bH = []
case3_bH = []
case4_bH = []
case5_bH = []
case6_bH = []

case1_a = []
case2_a = []
case3_a = []
case4_a = []
case5_a = []
case6_a = []

for alpha in alpha_theory_examples:
    output1 = Act_Temp_quick.theory(alpha, 1000, 1000)
    output2 = Act_Temp_quick.theory(alpha, 2000, 1000)
    output3 = Act_Temp_quick.theory(alpha, 1000, 2000)
    output4 = Act_Temp_quick.theory(alpha, 2000, 2000)
    output5 = Act_Temp_quick.theory(alpha, 1000, 4000)
    output6 = Act_Temp_quick.theory(alpha, 4000, 1000)
    
    if output1[4] > 10:
        case1_bH.append(output1[5])
        case1_a.append(output1[6])
    else:
        case1_bH.append(None)
        case1_a.append(None)

    if output2[4] > 10:
        case2_bH.append(output2[5])
        case2_a.append(output2[6])        
    else:
        case2_bH.append(None)
        case2_a.append(None)
    
    if output3[4] > 10:
        case3_bH.append(output3[5])
        case3_a.append(output3[6]) 
    else:
        case3_bH.append(None)
        case3_a.append(None)
        
    if output4[4] > 10:
        case4_bH.append(output4[5])
        case4_a.append(output4[6]) 
    else:
        case4_bH.append(None)
        case4_a.append(None)
                
    if output5[4] > 10:
        case5_bH.append(output5[5])
        case5_a.append(output5[6]) 
    else:
        case5_bH.append(None)
        case5_a.append(None)
    
    if output6[4] > 10:
        case6_bH.append(output6[5])
        case6_a.append(output6[6]) 
    else:
        case6_bH.append(None)
        case6_a.append(None)
# Out:
# /home/jupyter/TRIUMF-2019-Summer/2-3-4 Potential - Main Project/Act_Temp_quick.py:233: RuntimeWarning: divide by zero encountered in double_scalars
#   alpha_latent_at_N = field_energy_density_at_N/radiation_energy_density_at_N

# %%
plt.close()

plt.semilogy(alpha_theory_examples, case1_bH, 'ro-', label="\u039B = 1000 GeV, v = 1000 GeV")
plt.semilogy(alpha_theory_examples, case2_bH, 'bo-', label="\u039B = 2000 GeV, v = 1000 GeV")
plt.semilogy(alpha_theory_examples, case3_bH, 'yo-', label="\u039B = 1000 GeV, v = 2000 GeV")
plt.semilogy(alpha_theory_examples, case4_bH, 'go-', label="\u039B = 2000 GeV, v = 2000 GeV")
plt.semilogy(alpha_theory_examples, case5_bH, 'mo-', label="\u039B = 1000 GeV, v = 4000 GeV")
plt.semilogy(alpha_theory_examples, case6_bH, 'o-', label="\u039B = 4000 GeV, v = 1000 GeV")
plt.xlabel("\u03B1 (Potential's parameter)")
plt.ylabel("\u03B2/H at Nucleation Temperature")
plt.title("Comparing Nucleation Rate (\u03B2/H) at Nucleation Temperature, \nfor different 2-3-4 Potentials (\u03B1, \u039B, v)")
plt.grid(True)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="676">

# %%
plt.close()

# %%
plt.close()

plt.semilogy(alpha_theory_examples, case1_a, 'ro-', label="\u039B = 1000 GeV, v = 1000 GeV")
plt.semilogy(alpha_theory_examples, case2_a, 'bo-', label="\u039B = 2000 GeV, v = 1000 GeV")
plt.semilogy(alpha_theory_examples, case3_a, 'yo-', label="\u039B = 1000 GeV, v = 2000 GeV")
plt.semilogy(alpha_theory_examples, case4_a, 'go-', label="\u039B = 2000 GeV, v = 2000 GeV")
plt.semilogy(alpha_theory_examples, case5_a, 'mo-', label="\u039B = 1000 GeV, v = 4000 GeV")
plt.semilogy(alpha_theory_examples, case6_a, 'o-', label="\u039B = 4000 GeV, v = 1000 GeV")
plt.xlabel("\u03B1 (Potential's parameter)")
plt.ylabel("\u03B1_latent (at Nucleation Temperature)")
plt.title("Latent \'heat\' (\u03B1_latent) at Nucleation Temperature, \nfor different 2-3-4 Potentials (\u03B1, \u039B, v)")
plt.grid(True)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="691">

# %%
plt.close()

# %%
html_colors = ['maroon', 'coral', 'yellow', 'lime', 'aqua', 'teal', 'navy', 'mediumpurple', 'fuchsia']

plt.close()
plt.figure(figsize=[11, 8])
for i in range(len(alpha_theory_examples)):
    if case1_a[i] != None and case1_bH[i] != None:
        plt.loglog(case1_a[i], case1_bH[i], color=html_colors[i], marker='o')
    if case2_a[i] != None and case2_bH[i] != None:
        plt.loglog(case2_a[i], case2_bH[i], color=html_colors[i], marker='^')
    if case3_a[i] != None and case3_bH[i] != None:    
        plt.loglog(case3_a[i], case3_bH[i], color=html_colors[i], marker='D')
    if case4_a[i] != None and case4_bH[i] != None:    
        plt.loglog(case4_a[i], case4_bH[i], color=html_colors[i], marker='*')
    if case5_a[i] != None and case5_bH[i] != None:    
        plt.loglog(case5_a[i], case5_bH[i], color=html_colors[i], marker='+')
    if case6_a[i] != None and case6_bH[i] != None:    
        plt.loglog(case6_a[i], case6_bH[i], color=html_colors[i], marker='x')
plt.grid(True)
plt.xlabel("\u03B1_latent at Nucleation Temperature")
plt.ylabel("\u03B2/H at Nucleation Temperature")
plt.title("Nucleation rate (\u03B2/H) vs. Latent heat (\u03B1_latent), at Nucleation Temperature, \nfor various 2-3-4 Potentials")
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# Text(0.5, 1.0, 'Nucleation rate (β/H) vs. Latent heat (α_latent), at Nucleation Temperature, \nfor various 2-3-4 Potentials')

# %%
plt.close()

# %%
a_data_template = []    
s_data_dof_3 = []
s_data_dof_4 = []
r_data_dof_3 = []
r_data_dof_4 = []

file2 = open("S_alpha_template_alpha_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        a_data_template.append(float(word2))
file2.close()

file2 = open("S_alpha_template_dof_3_S_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        s_data_dof_3.append(float(word2))
file2.close()

file2 = open("S_alpha_template_dof_4_S_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        s_data_dof_4.append(float(word2))
file2.close()

file2 = open("S_alpha_template_dof_3_R_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        r_data_dof_3.append(float(word2))
file2.close()

file2 = open("S_alpha_template_dof_4_R_vals.txt", "r")
for line2 in file2:
    for word2 in line2.split(): 
        r_data_dof_4.append(float(word2))
file2.close()

a_data_template_3 = a_data_template
a_data_template_4 = a_data_template

# %%
######
# Want to use best guess Pchip -> not just linearization
a_data_template = np.array(a_data_template)

compare1 = list(abs(a_data_template - 0.506))
find_index1 = compare1.index(min(compare1))
if a_data_template[find_index1] > 0.506:
    find_index1 = find_index1 + 1

compare2 = list(abs(a_data_template - 0.513))
find_index2 = compare2.index(min(compare2))
if a_data_template[find_index2] < 0.513:
    find_index2 = find_index2 - 1

compare3 = list(abs(a_data_template - 0.522))
find_index4 = compare3.index(min(compare3))
if a_data_template[find_index4] < 0.522:
    find_index4 = find_index4 - 1

a1_3 = list(a_data_template)[:(find_index2 + 1)]
a2_3 = list(a_data_template)[find_index1:] 
a3_3 = list(a_data_template)[(find_index2 + 1):find_index1]

a1_4 = list(a_data_template)[:(find_index4 + 1)]
a2_4 = list(a_data_template)[find_index1:] 
a3_4 = list(a_data_template)[(find_index4 + 1):find_index1]

s3_vals = list(s_data_dof_3[:len(a1_3)])
for y in s_data_dof_3[find_index1:]:
    s3_vals.append(y)
s_data_dof_3 = np.array(s3_vals)

r3_vals = list(r_data_dof_3[:len(a1_3)])
for y in r_data_dof_3[find_index1:]:
    r3_vals.append(y)
r_data_dof_3 = np.array(r3_vals)

a3_vals = a1_3[:]
for x in a2_3:
    a3_vals.append(x)
a_data_template_3 = np.array(a3_vals)

s4_vals = list(s_data_dof_4[:len(a1_4)])
for y in s_data_dof_4[find_index1:]:
    s4_vals.append(y)
s_data_dof_4 = np.array(s4_vals)

r4_vals = list(r_data_dof_4[:len(a1_4)])
for y in r_data_dof_4[find_index1:]:
    r4_vals.append(y)
r_data_dof_4 = np.array(r4_vals)

a4_vals = a1_4[:]
for x in a2_4:
    a4_vals.append(x)
a_data_template_4 = np.array(a4_vals)

# Get rid of above code if just want to use linearization
######
alpha_eff_array = np.linspace(0.5, 0.75, 10000)

curve_fit_S_4 = sci.PchipInterpolator(a_data_template_4[::-1], s_data_dof_4[::-1])
curve_fit_R_4 = sci.PchipInterpolator(a_data_template_4[::-1], r_data_dof_4[::-1])

curve_fit_S_3 = sci.PchipInterpolator(a_data_template_3[::-1], s_data_dof_3[::-1])
curve_fit_R_3 = sci.PchipInterpolator(a_data_template_3[::-1], r_data_dof_3[::-1])

S_array_3 = curve_fit_S_3(alpha_eff_array)
R_array_3 = curve_fit_R_3(alpha_eff_array)

S_array_4 = curve_fit_S_4(alpha_eff_array)
R_array_4 = curve_fit_R_4(alpha_eff_array)

# %%
plt.close()

plt.figure(figsize=[10, 8.5])
plt.semilogy(alpha_eff_array, S_array_3, 'r.-', label='D=3')
plt.semilogy(alpha_eff_array, S_array_4, 'b.-', label='D=4')
plt.xlabel("\u03B1 (Potential's parameter)")
plt.ylabel("Dimensionless Euclidean action, S")
plt.title("S vs.\u03B1")
#plt.xlim(0.497, 0.53)
plt.grid(True)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
plt.close()

# %%
plt.close()

V = lambda x: (1.5 - 2*0.6)*x**2 - x**3 + 0.6*x**4
x_array = np.linspace(-0.1, 1.2, 10000)

plt.figure(figsize=[11, 7])
plt.plot(x_array, V(x_array) - V(1), 'g-', label='V(x, T=0) Normalized to V(x=v, T=0) = 0')
plt.plot([-0.1, 1.2], [0, 0], 'k-', linewidth=3)
plt.plot([-0.1, 1.2], [-1*V(1), -1*V(1)], 'k--', linewidth=3)
plt.plot([0, 0], [0, V(0.35) - V(1) + 0.02], 'k-', linewidth=3)
plt.plot(0, -1*V(1), 'r*', label='Metastable state a.k.a. False Vacuum')
plt.plot(1, 0, 'b*', label='Stable state a.k.a. True Vacuum')
plt.xlabel("Field strength 'x'")
plt.ylabel("Energy Density of Field '\u03C1(x)'")
plt.title("V(x) = \u039B\u2074((1.5 - 2\u03B1)(x/v)\u00B2 - (x/v)\u00B3 + \u03B1 (x/v)\u2074) \n \u03B1 = 0.6, \u039B = 1, v = 1")
plt.grid(True)
plt.legend(loc=1)
# Out:
# <img src="data:image/png;base64,..." width="792">

# %%
plt.close()
